# %%
# slow down a bit when hacking something together, e.g. I forgot to add a simple function call 
# tuple unpacking is nice, but cannot be done in a nested list comprehension
# don't forget .items in  for k,v in dict.items()
# use hashlib for md5 encodings
# multiline list comprehensions don't need extra parentheses, but multiline if statements do
# np.clip min and max can be omitted by specifying None

# %%
import numpy as np

# %%
# part 1
f=open('input.txt')
lines = [line.rstrip('\n') for line in f]
grid = np.zeros((1000,1000))
# print amount of rows and first 100 character of first line
len(lines), lines[0][:100]
for line in lines:
    match = re.findall(r'(\d+)',line)
    a,b,c,d = int(match[0]),int(match[1]),int(match[2]),int(match[3])
    if 'turn off' in line: grid[a:c+1,b:d+1] = 0
    elif 'turn on' in line: grid[a:c+1,b:d+1] = 1
    elif 'toggle' in line: grid[a:c+1,b:d+1] = 1-grid[a:c+1,b:d+1]
    else: print('error')
np.sum(grid)
# Out:
# 543903.0

# %%
plt.imshow(grid)

# %%
# part 2
f=open('input.txt')
lines = [line.rstrip('\n') for line in f]
grid = np.zeros((1000,1000))
# print amount of rows and first 100 character of first line
len(lines), lines[0][:100]
for line in lines:
    match = re.findall(r'(\d+)',line)
    a,b,c,d = int(match[0]),int(match[1]),int(match[2]),int(match[3])
    if 'turn off' in line: grid[a:c+1,b:d+1] = np.clip(grid[a:c+1,b:d+1]-1,0,None)
    elif 'turn on' in line: grid[a:c+1,b:d+1] = grid[a:c+1,b:d+1]+1
    elif 'toggle' in line: grid[a:c+1,b:d+1] = grid[a:c+1,b:d+1]+2
    else: print('error')
np.sum(grid)
# Out:
# 14687245.0

# %%
import aoc
a,b,c,d = aoc.to_int(match)
a,b,c,d
# Out:
# (222, 12, 856, 241)

# %%
plt.imshow(grid)

# %%
line.strip().rsplit(' ', 3)
# Out:
# ['turn on', '222,12', 'through', '856,241']
