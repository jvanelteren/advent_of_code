# %%
import sys
scores_recipes = (3,7)
index_recipes = (0,1)

board = [3,7,1,0]
target=[2,8,6,0,5,1]
global targetindex
targetindexstop=6
targetindex=0


def checktarget(result):
    global targetindex
    if target[targetindex]==result:
        targetindex=targetindex+1
        #print ('targetindex',targetindex)
        wincondition()
    else:
        targetindex =0
def wincondition():
    #print (targetindex,targetindexstop)
    if targetindex==targetindexstop:
        #print ('done',board)
        print (len(board)-len(target)+1)
        sys.exit(0)

def add_scores(scores_recipes):
    result = sum(scores_recipes)
    #print (result)
    if result < 10:
        board.append(result)
        checktarget(result)
        wincondition
        
    else:
        board.append(result//10)
        checktarget(result//10)
        wincondition
        board.append(result%10)
        checktarget(result%10)
        wincondition
    #print ('board',board)
    
def change_scores(index_recipes):
    score0 = board[index_recipes[0]]
    score1 = board[index_recipes[1]]
    #print ('scores',(score0,score1))
    return (score0,score1)
    
def get_new_indices(index_recipes,scores_recipes):
    elf0 = pick_newindex(index_recipes[0],scores_recipes[0])
    elf1 = pick_newindex(index_recipes[1],scores_recipes[1])
    #print ('indices',(elf0,elf1))
    return (elf0,elf1)

def pick_newindex(index,score):
    
    newindex = 1+index+score
    if newindex>=len(board):
        #print ('newindex{},len(board){},currentindex{}'.format(newindex,len(board),index))
        newindex -= len(board)
    #print ('elf index{},score{},newindex{}'.format(index,score,newindex))
    return newindex
   
def go():
    global index_recipes,scores_recipes
    for x in range (100286071):
        if x%100000==0: print (x)

        add_scores(scores_recipes)
        index_recipes=get_new_indices(index_recipes,scores_recipes)
        scores_recipes = change_scores(index_recipes)
        #print (board)
    
# %load_ext line_profiler                
# %lprun -f go go()
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
# 4100000
# 4200000
# 4300000
# 4400000
# 4500000
# 4600000
# 4700000
# 4800000
# 4900000
# 5000000
# 5100000
# 5200000
# 5300000
# 5400000
# 5500000
# 5600000
# 5700000
# 5800000
# 5900000
# 6000000
# 6100000
# 6200000
# 6300000
# 6400000
# 6500000
# 6600000
# 6700000
# 6800000
# 6900000
# 7000000
# 7100000
# 7200000
# 7300000
# 7400000
# 7500000
# 7600000
# 7700000
# 7800000
# 7900000
# 8000000
# 8100000
# 8200000
# 8300000
# 8400000
# 8500000
# 8600000
# 8700000
# 8800000
# 8900000
# 9000000
# ...

# %%
boardstring.find('286051')
# Out:
# -1

# %%
(3)[7]
(3)[7] 1  0 
 3  7  1 [0](1) 0 
 3  7  1  0 [1] 0 (1)
(3) 7  1  0  1  0 [1] 2 
 3  7  1  0 (1) 0  1  2 [4]
 3  7  1 [0] 1  0 (1) 2  4  5
# Out:
# 1

# %%
for x in range (286071):
    if x%100000==0: print (x)
    
    add_scores(scores_recipes)
    index_recipes=get_new_indices(index_recipes,scores_recipes)
    scores_recipes = change_scores(index_recipes)
    #print (board)
    
    if len(board)>=286051+10:
        print ('ready',board[286051:286051+11])
        result = ''.join(str(e) for e in board[286051:286051+11])
        boardstring = ''.join(str(e) for e in board)
        
        print (result)
        print (boardstring.find('51589'))
        
        sys.exit(0)
