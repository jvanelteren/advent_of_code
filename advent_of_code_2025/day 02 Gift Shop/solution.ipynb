# %%
from aocutils.math import factors
from itertools import batched
# mistake to take the factors of int(x) instead of len(int(x))
lines = open("in.txt").read().strip().split(",")
invalid = 0
for line in lines:
    print(line)
    a,b = line.split('-')
    a,b = int(a), int(b)
    for x in range(a,b+1):
        x = str(x)
        fac = sorted(list(factors(len(x))))[:-1] # no chunck in 1
        n = len(str(x))
        for f in fac:
            # original
            # if len((a:=set((x[idx:idx+f]) for idx in range(0,n,f)))) == 1:
            
            # improved
            if len(set(batched(x,f))) == 1:
                invalid += int(x)
                break
invalid
# Out:
# 16100064-16192119
# 2117697596-2117933551
# 1-21
# 9999936269-10000072423
# 1770-2452
# 389429-427594
# 46633-66991
# 877764826-877930156
# 880869-991984
# 18943-26512
# 7216-9427
# 825-1162
# 581490-647864
# 2736-3909
# 39327886-39455605
# 430759-454012
# 1178-1741
# 219779-244138
# 77641-97923
# 1975994465-1976192503
# 3486612-3602532
# 277-378
# 418-690
# 74704280-74781349
# 3915-5717
# 665312-740273
# 69386294-69487574
# 2176846-2268755
# 26-45
# 372340114-372408052
# 7996502103-7996658803
# 7762107-7787125
# 48-64
# 4432420-4462711
# 130854-178173
# 87-115
# 244511-360206
# 69-86
# 31898925685

# %%
97 * 10101
# Out:
# 979797

# %%
12345 * 10101010101
# Out:
# 124696969696845
