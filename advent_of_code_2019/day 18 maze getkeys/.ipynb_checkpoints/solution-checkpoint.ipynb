# %%
import numpy as np
import networkx as nx
np.set_printoptions(threshold=100)

f=open('test3.txt') #not with read because thats probably the whole file
lines = [list(line.rstrip('\n')) for line in f]
grid = np.array(lines)

# %%
class Pos():
    def __init__(self,input):
        self.x,self.y = input[0],input[1]
        self.loc = input
        self.n = getneigh((self.x,self.y))
        self.value = grid[input]
        self.door,self.key = False,False
        if self.value.isupper(): self.door = True
        elif self.value.islower(): self.key = True
    def enter(self,keys):
        if self.door:
            values = [(locations[k].value).upper() for k in keys]
            if self.value in values: return self.loc
            else: return False
        else: return self.loc
    def __repr__(self):
        return f'({self.x},{self.y}) {self.value} is door {self.door} is key {self.key}'

# %%
locations = set([tuple(i) for i in np.argwhere(grid!='#')])
def getneigh(i):
  res = []
  if (i[0],i[1]+1) in locations: res.append((i[0],i[1]+1))
  if (i[0],i[1]-1) in locations: res.append((i[0],i[1]-1))
  if (i[0]+1,i[1]) in locations: res.append((i[0]+1,i[1]))
  if (i[0]-1,i[1]) in locations: res.append((i[0]-1,i[1]))
  return res
neigh = {tuple(i):getneigh(tuple(i)) for i in np.argwhere(grid!='#')}

# %%
locations = {tuple(i):Pos(tuple(i)) for i in np.argwhere(grid!='#')}
doors = [i.loc for i in locations.values() if i.door]
keys = [i.loc for i in locations.values() if i.key]

# %%
def get_potentials(keyset,current_loc): #return keys that are reachable, given a keyset and current_loc
    # print('getpotentials',keyset,current_loc)
    access = [v.enter(keyset) for v in locations.values() if v.enter(keyset) ]
    noaccess = [v.loc for v in locations.values() if not v.enter(keyset) ]

    g = nx.Graph()
    g.add_nodes_from(access)
    for a in locations: # for each location (without the doors)
        for n in locations[a].n: #for each neighbor
            g.add_edge(a,n)
    g.remove_nodes_from(noaccess)
    reachable =  nx.algorithms.descendants(g, current_loc)
    reachable_keys = {k for k in keys if k in reachable}
    relevant_keys  = reachable_keys-set(keyset)
    return {k: nx.shortest_path_length(g,current_loc,k) for k in relevant_keys}

# %%
paths = []
distances = []
from copy import deepcopy
def step(keyset,loc,length):
    res = get_potentials(keyset,loc)
    # print('possible keys for',keyset,loc,res)
    # print(len(res))
    if not res: 
        paths.append(keyset)
        distances.append(length)
    else:
        if len(res)==1:
            i = next(iter(res))
            return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
        else:
            return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
current_loc = tuple(np.argwhere(grid=='@')[0])
test = step([current_loc],current_loc,[])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-beb1cd25e1b0> in <module>
#      16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
# ---> 18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in <listcomp>(.0)
#      14             return step(deepcopy(keyset)+[i],i,deepcopy(length)+[res[i]])
#      15         else:
# ---> 16             return [step(deepcopy(keyset)+[k],k,deepcopy(length)+[v]) for k,v in res.items()]
#      17 current_loc = tuple(np.argwhere(grid=='@')[0])
#      18 test = step([current_loc],current_loc,[])
#
# <ipython-input-66-beb1cd25e1b0> in step(keyset, loc, length)
#       3 from copy import deepcopy
#       4 def step(keyset,loc,length):
# ----> 5     res = get_potentials(keyset,loc)
#       6     # print('possible keys for',keyset,loc,res)
#       7     # print(len(res))
#
# <ipython-input-64-f339359e3940> in get_potentials(keyset, current_loc)
#      10             g.add_edge(a,n)
#      11     g.remove_nodes_from(noaccess)
# ---> 12     reachable =  nx.algorithms.descendants(g, current_loc)
#      13     reachable_keys = {k for k in keys if k in reachable}
#      14     relevant_keys  = reachable_keys-set(keyset)
#
# C:\ProgramData\Miniconda3\lib\site-packages\networkx\algorithms\dag.py in descendants(G, source)
#      71     if not G.has_node(source):
#      72         raise nx.NetworkXError("The node %s is not in the graph." % source)
# ---> 73     des = set(n for n, d in nx.shortest_path_length(G, source=source).items())
#      74     return des - {source}
#      75
#
# C:\ProgramData\Miniconda3\lib\site-packages\networkx\algorithms\shortest_paths\generic.py in shortest_path_length(G, source, target, weight, method)
#     300             # Find paths to all nodes accessible from the source.
#     301             if method == 'unweighted':
# --> 302                 paths = nx.single_source_shortest_path_length(G, source)
#     303             elif method == 'dijkstra':
#     304                 path_length = nx.single_source_dijkstra_path_length
#
# C:\ProgramData\Miniconda3\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in single_source_shortest_path_length(G, source, cutoff)
#      59     shortest_path_length
#      60     """
# ---> 61     if source not in G:
#      62         raise nx.NodeNotFound('Source {} is not in G'.format(source))
#      63     if cutoff is None:
#
# C:\ProgramData\Miniconda3\lib\site-packages\networkx\classes\graph.py in __contains__(self, n)
#     423         True
#     424         """
# --> 425         try:
#     426             return n in self._node
#     427         except TypeError:
#
# KeyboardInterrupt:

# %%
paths[:10]
# Out:
# [[(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (1, 1),
#   (3, 6),
#   (5, 15),
#   (1, 15)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (1, 1),
#   (3, 6),
#   (1, 15),
#   (5, 15)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (1, 1),
#   (1, 15),
#   (3, 6),
#   (5, 15)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (3, 6),
#   (5, 15),
#   (1, 1),
#   (1, 15)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (3, 6),
#   (5, 15),
#   (1, 15),
#   (1, 1)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (3, 6),
#   (1, 1),
#   (5, 15),
#   (1, 15)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (3, 6),
#   (1, 1),
#   (1, 15),
#   (5, 15)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (3, 6),
#   (1, 15),
#   (5, 15),
#   (1, 1)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (3, 6),
#   (1, 15),
#   (1, 1),
#   (5, 15)],
#  [(4, 8),
#   (5, 10),
#   (5, 6),
#   (3, 10),
#   (7, 1),
#   (7, 6),
#   (3, 15),
#   (3, 1),
#   (1, 6),
#   (7, 15),
#   (1, 10),
#   (5, 1),
#   (7, 10),
#   (1, 15),
#   (1, 1),
#   (3, 6),
#   (5, 15)]]

# %%
sum(distances[0])
# Out:
# 6082

# %%
for p in paths[2]:
    print(locations[p].value)
# Out:
# @
# a
# b
# d
# c
# e
# f

# %%
distances
# Out:
# [86, 114, 86]

# %%
{1:0,2:0}.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-3105e568888c> in <module>
# ----> 1 {1:0,2:0}.pop()
#
# TypeError: pop expected at least 1 arguments, got 0
